# %% [markdown]
# <a href="https://colab.research.google.com/github/liam77773smith/cb2330-portfolio/blob/main/Exercise1b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The formula for the Binomial Coeficient shows how many ways to choose  k  things out of  N:
#
# ${N\choose k}$ = $\frac{N!}{k!(N-k)!}$

# %%
def Binomial_Coefficient(k, N):
  if k>N:
    print("undefined")
    return None
  elif k == N or k==0
    return 1
  else:
    result = 1
    for i in range(1, k + 1):
        #In progress
